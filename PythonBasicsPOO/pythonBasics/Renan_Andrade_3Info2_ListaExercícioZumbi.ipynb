# %% [markdown]
# 1) Faça um programa que peça dois números inteiros e imprima a soma desses dois números

# %%
print(int(input("Digite o primeiro número da soma: ")) + int(input("Digite o segundo número da soma: ")))
# Out:
# Digite o primeiro número da soma:10
# Digite o segundo número da soma:20
# 30

# %% [markdown]
# 2) Escreva um programa que leia um valor em metros e o exiba convertido em milímetros

# %%
print(float(input("Digite p valor, em metros, a ser convertido em milímetros: ")) * 1000, "milímetros")
# Out:
# Digite p valor, em metros, a ser convertido em milímetros: 1
# 1000.0 milímetros

# %% [markdown]
# 3) Escreva um programa que leia a quantidade de dias, horas, minutos e segundos do usuário. Calcule o total em segundos.

# %% [markdown]
# 10) Escreva um programa para calcular a redução do tempo de vida de um fumante. Pergunte a quantidade de cigarros fumados por dia e quantos anos ele já fumou. Considere que um fumante perde 10 minutos de vida a cada cigarro, calcule quantos dias de vida um fumante perderá. Exiba o total de dias.

# %% [markdown]
# 9) Escreva um programa que pergunte a quantidade de km percorridos por um carro alugado pelo usuário, assim como a quantidade de dias pelos quais o carro foi alugado. Calcule o preço a pagar, sabendo que o carro custa R$ 60,00 por dia e R$ 0,15 por km rodado.

# %%
print((float(input('Quantidade de dias com o carro alugado: \n ─>')) * 60.00) + (float(input('Quantidade de kilômetros percorridos com o carro: \n ─>')) * 0.15))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-173f4b3b4b7f> in <module>
# ----> 1 print((float(input('Quantidade de dias com o carro alugado: \n ─>')) * 60.00) + (float(input('Quantidade de kilômetros percorridos com o carro: \n ─>')) * 0.15))
#
# ValueError: could not convert string to float: ''

# %%
print((int(input("Quantos cigarros o indivíduo fuma por dia? \n ─> ")) * (10 / 60 / 24)) * float(input("Quantos anos esteve fumando? \n ─> ")) * 365, "dias de vida perdidos")
# Out:
# Quantos cigarros o indivíduo fuma por dia?
#  ─> 1
# Quantos anos esteve fumando?
#  ─> 1
# 2.534722222222222 dias de vida perdidos

# %% [markdown]
# 11) Sabendo que str( ) converte valores numéricos para string, calcule quantos dígitos há em 2 elevado a um milhão.

# %%
print(len(str(int(2 ** (10 ** 5)))), 'dígitos')
# Out:
# 30103 dígitos

# %%
print(float(input("Quantidade de segundos: \n ─>")) + float(input("Quantidade de minutos: \n ─>")) * 60 + float(input("Quantidade de horas: \n ─>")) * 60 * 60 + float(input('Quantidade de dias: \n ─>')) * 24 * 60 * 60)
# Out:
# 98400.0
